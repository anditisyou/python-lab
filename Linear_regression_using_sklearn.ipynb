# %%
import pandas as pd
import numpy as np
# LOAD DATASET
df = pd.read_csv("Housing.csv")
df
# Out:
#         price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    13300000  7420         4          2        3      yes        no       no
# 1    12250000  8960         4          4        4      yes        no       no
# 2    12250000  9960         3          2        2      yes        no      yes
# 3    12215000  7500         4          2        2      yes        no      yes
# 4    11410000  7420         4          1        2      yes       yes      yes
# ..        ...   ...       ...        ...      ...      ...       ...      ...
# 540   1820000  3000         2          1        1      yes        no      yes
# 541   1767150  2400         3          1        1       no        no       no
# 542   1750000  3620         2          1        1      yes        no       no
# 543   1750000  2910         3          1        1       no        no       no
# 544   1750000  3850         3          1        2      yes        no       no
#
# ...

# %%
X = dp['price']
Y = dp['area']

# %%
# 2d : array
X = np.array(X).reshape(-1,1)
Y = np.array(Y).reshape(-1,1)

# %%
print(len(X))
print(len(Y))
# Out:
# 545
# 545

# %%
# split the datset using train_test_split() method
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(X,Y,test_size=0.2)

# %%
print(f"Total training inputs : {len(x_train),len(y_train)}")
print(f"Total testing inputs : {len(x_test),len(y_test)}")
# Out:
# Total training inputs : (436, 436)
# Total testing inputs : (109, 109)

# %%
# manually spliting the dataset 
#x_train=X[:436]
#x_test=X[436:]
#y_train=X[:436]
#y_test=X[436:]

# %%
print(f"Total training inputs : {len(x_train),len(y_train)}")
print(f"Total testing inputs : {len(x_test),len(y_test)}")
# Out:
# Total training inputs : (436, 436)
# Total testing inputs : (109, 109)

# %%
# importing libraries for plotting the dataset for linear regression
import matplotlib.pyplot as plt

#plt.scatter(x_test, y_test, marker="x")
plt.scatter(x_train, y_train, marker="x", color='r')
plt.xlabel("Price")
plt.ylabel("Area")
plt.show()

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import r2_score, mean_squared_error

# scale
scaler = StandardScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

# create model
model_linreg = LinearRegression()

# train model
model_linreg.fit(x_train, y_train)

# predict
y_pred_val = model_linreg.predict(x_test)

# evaluate
print("R2:", r2_score(y_test, y_pred_val))
print("MSE:", mean_squared_error(y_test, y_pred_val))
# Out:
# R2: 0.1861861153114801
# MSE: 4014452.3194135283

# %%
plt.plot(x_test, y_pred_val)
plt.scatter(x_train, y_train, marker="x", color='r')
plt.xlabel("Price")
plt.ylabel("Area")
plt.show()
