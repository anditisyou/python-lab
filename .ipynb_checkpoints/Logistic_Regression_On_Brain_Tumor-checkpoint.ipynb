# %%
#importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

dp = pd.read_csv("Brain_Tumor (4).csv")
X = dp['price'].values   # column price
Y = dp['area'].values    # column area

#show all training examples
for i in range(len(X)):
    #print("(X[",i,"],Y[",i,"]) =",X[i],Y[i])
    print(f"(X[i],Y[i]) = ({X[i]},{Y[i]})")
# Out:
# (X[i],Y[i]) = (13300000,7420)
# (X[i],Y[i]) = (12250000,8960)
# (X[i],Y[i]) = (12250000,9960)
# (X[i],Y[i]) = (12215000,7500)
# (X[i],Y[i]) = (11410000,7420)
# (X[i],Y[i]) = (10850000,7500)
# (X[i],Y[i]) = (10150000,8580)
# (X[i],Y[i]) = (10150000,16200)
# (X[i],Y[i]) = (9870000,8100)
# (X[i],Y[i]) = (9800000,5750)
# (X[i],Y[i]) = (9800000,13200)
# (X[i],Y[i]) = (9681000,6000)
# (X[i],Y[i]) = (9310000,6550)
# (X[i],Y[i]) = (9240000,3500)
# (X[i],Y[i]) = (9240000,7800)
# (X[i],Y[i]) = (9100000,6000)
# (X[i],Y[i]) = (9100000,6600)
# (X[i],Y[i]) = (8960000,8500)
# (X[i],Y[i]) = (8890000,4600)
# (X[i],Y[i]) = (8855000,6420)
# (X[i],Y[i]) = (8750000,4320)
# (X[i],Y[i]) = (8680000,7155)
# (X[i],Y[i]) = (8645000,8050)
# (X[i],Y[i]) = (8645000,4560)
# (X[i],Y[i]) = (8575000,8800)
# (X[i],Y[i]) = (8540000,6540)
# (X[i],Y[i]) = (8463000,6000)
# (X[i],Y[i]) = (8400000,8875)
# (X[i],Y[i]) = (8400000,7950)
# (X[i],Y[i]) = (8400000,5500)
# (X[i],Y[i]) = (8400000,7475)
# (X[i],Y[i]) = (8400000,7000)
# (X[i],Y[i]) = (8295000,4880)
# (X[i],Y[i]) = (8190000,5960)
# (X[i],Y[i]) = (8120000,6840)
# (X[i],Y[i]) = (8080940,7000)
# (X[i],Y[i]) = (8043000,7482)
# (X[i],Y[i]) = (7980000,9000)
# (X[i],Y[i]) = (7962500,6000)
# (X[i],Y[i]) = (7910000,6000)
# (X[i],Y[i]) = (7875000,6550)
# (X[i],Y[i]) = (7840000,6360)
# (X[i],Y[i]) = (7700000,6480)
# (X[i],Y[i]) = (7700000,6000)
# (X[i],Y[i]) = (7560000,6000)
# (X[i],Y[i]) = (7560000,6000)
# (X[i],Y[i]) = (7525000,6000)
# (X[i],Y[i]) = (7490000,6600)
# (X[i],Y[i]) = (7455000,4300)
# (X[i],Y[i]) = (7420000,7440)
# (X[i],Y[i]) = (7420000,7440)
# (X[i],Y[i]) = (7420000,6325)
# (X[i],Y[i]) = (7350000,6000)
# (X[i],Y[i]) = (7350000,5150)
# (X[i],Y[i]) = (7350000,6000)
# (X[i],Y[i]) = (7350000,6000)
# (X[i],Y[i]) = (7343000,11440)
# (X[i],Y[i]) = (7245000,9000)
# (X[i],Y[i]) = (7210000,7680)
# (X[i],Y[i]) = (7210000,6000)
# (X[i],Y[i]) = (7140000,6000)
# (X[i],Y[i]) = (7070000,8880)
# (X[i],Y[i]) = (7070000,6240)
# (X[i],Y[i]) = (7035000,6360)
# (X[i],Y[i]) = (7000000,11175)
# (X[i],Y[i]) = (6930000,8880)
# (X[i],Y[i]) = (6930000,13200)
# (X[i],Y[i]) = (6895000,7700)
# (X[i],Y[i]) = (6860000,6000)
# (X[i],Y[i]) = (6790000,12090)
# (X[i],Y[i]) = (6790000,4000)
# (X[i],Y[i]) = (6755000,6000)
# (X[i],Y[i]) = (6720000,5020)
# (X[i],Y[i]) = (6685000,6600)
# (X[i],Y[i]) = (6650000,4040)
# (X[i],Y[i]) = (6650000,4260)
# (X[i],Y[i]) = (6650000,6420)
# (X[i],Y[i]) = (6650000,6500)
# (X[i],Y[i]) = (6650000,5700)
# (X[i],Y[i]) = (6650000,6000)
# (X[i],Y[i]) = (6629000,6000)
# (X[i],Y[i]) = (6615000,4000)
# (X[i],Y[i]) = (6615000,10500)
# (X[i],Y[i]) = (6580000,6000)
# (X[i],Y[i]) = (6510000,3760)
# (X[i],Y[i]) = (6510000,8250)
# (X[i],Y[i]) = (6510000,6670)
# (X[i],Y[i]) = (6475000,3960)
# (X[i],Y[i]) = (6475000,7410)
# (X[i],Y[i]) = (6440000,8580)
# (X[i],Y[i]) = (6440000,5000)
# (X[i],Y[i]) = (6419000,6750)
# (X[i],Y[i]) = (6405000,4800)
# (X[i],Y[i]) = (6300000,7200)
# (X[i],Y[i]) = (6300000,6000)
# (X[i],Y[i]) = (6300000,4100)
# (X[i],Y[i]) = (6300000,9000)
# (X[i],Y[i]) = (6300000,6400)
# (X[i],Y[i]) = (6293000,6600)
# (X[i],Y[i]) = (6265000,6000)
# (X[i],Y[i]) = (6230000,6600)
# (X[i],Y[i]) = (6230000,5500)
# (X[i],Y[i]) = (6195000,5500)
# (X[i],Y[i]) = (6195000,6350)
# (X[i],Y[i]) = (6195000,5500)
# (X[i],Y[i]) = (6160000,4500)
# (X[i],Y[i]) = (6160000,5450)
# (X[i],Y[i]) = (6125000,6420)
# (X[i],Y[i]) = (6107500,3240)
# (X[i],Y[i]) = (6090000,6615)
# (X[i],Y[i]) = (6090000,6600)
# (X[i],Y[i]) = (6090000,8372)
# (X[i],Y[i]) = (6083000,4300)
# (X[i],Y[i]) = (6083000,9620)
# (X[i],Y[i]) = (6020000,6800)
# (X[i],Y[i]) = (6020000,8000)
# (X[i],Y[i]) = (6020000,6900)
# (X[i],Y[i]) = (5950000,3700)
# (X[i],Y[i]) = (5950000,6420)
# (X[i],Y[i]) = (5950000,7020)
# (X[i],Y[i]) = (5950000,6540)
# (X[i],Y[i]) = (5950000,7231)
# (X[i],Y[i]) = (5950000,6254)
# (X[i],Y[i]) = (5950000,7320)
# (X[i],Y[i]) = (5950000,6525)
# (X[i],Y[i]) = (5943000,15600)
# (X[i],Y[i]) = (5880000,7160)
# (X[i],Y[i]) = (5880000,6500)
# (X[i],Y[i]) = (5873000,5500)
# (X[i],Y[i]) = (5873000,11460)
# (X[i],Y[i]) = (5866000,4800)
# (X[i],Y[i]) = (5810000,5828)
# (X[i],Y[i]) = (5810000,5200)
# (X[i],Y[i]) = (5810000,4800)
# (X[i],Y[i]) = (5803000,7000)
# (X[i],Y[i]) = (5775000,6000)
# (X[i],Y[i]) = (5740000,5400)
# (X[i],Y[i]) = (5740000,4640)
# (X[i],Y[i]) = (5740000,5000)
# (X[i],Y[i]) = (5740000,6360)
# (X[i],Y[i]) = (5740000,5800)
# (X[i],Y[i]) = (5652500,6660)
# (X[i],Y[i]) = (5600000,10500)
# (X[i],Y[i]) = (5600000,4800)
# (X[i],Y[i]) = (5600000,4700)
# (X[i],Y[i]) = (5600000,5000)
# (X[i],Y[i]) = (5600000,10500)
# (X[i],Y[i]) = (5600000,5500)
# (X[i],Y[i]) = (5600000,6360)
# (X[i],Y[i]) = (5600000,6600)
# (X[i],Y[i]) = (5600000,5136)
# (X[i],Y[i]) = (5565000,4400)
# (X[i],Y[i]) = (5565000,5400)
# (X[i],Y[i]) = (5530000,3300)
# (X[i],Y[i]) = (5530000,3650)
# (X[i],Y[i]) = (5530000,6100)
# (X[i],Y[i]) = (5523000,6900)
# (X[i],Y[i]) = (5495000,2817)
# (X[i],Y[i]) = (5495000,7980)
# (X[i],Y[i]) = (5460000,3150)
# (X[i],Y[i]) = (5460000,6210)
# (X[i],Y[i]) = (5460000,6100)
# (X[i],Y[i]) = (5460000,6600)
# (X[i],Y[i]) = (5425000,6825)
# (X[i],Y[i]) = (5390000,6710)
# (X[i],Y[i]) = (5383000,6450)
# (X[i],Y[i]) = (5320000,7800)
# (X[i],Y[i]) = (5285000,4600)
# (X[i],Y[i]) = (5250000,4260)
# (X[i],Y[i]) = (5250000,6540)
# (X[i],Y[i]) = (5250000,5500)
# (X[i],Y[i]) = (5250000,10269)
# (X[i],Y[i]) = (5250000,8400)
# (X[i],Y[i]) = (5250000,5300)
# (X[i],Y[i]) = (5250000,3800)
# (X[i],Y[i]) = (5250000,9800)
# (X[i],Y[i]) = (5250000,8520)
# (X[i],Y[i]) = (5243000,6050)
# (X[i],Y[i]) = (5229000,7085)
# (X[i],Y[i]) = (5215000,3180)
# (X[i],Y[i]) = (5215000,4500)
# (X[i],Y[i]) = (5215000,7200)
# (X[i],Y[i]) = (5145000,3410)
# (X[i],Y[i]) = (5145000,7980)
# (X[i],Y[i]) = (5110000,3000)
# (X[i],Y[i]) = (5110000,3000)
# (X[i],Y[i]) = (5110000,11410)
# (X[i],Y[i]) = (5110000,6100)
# (X[i],Y[i]) = (5075000,5720)
# (X[i],Y[i]) = (5040000,3540)
# (X[i],Y[i]) = (5040000,7600)
# (X[i],Y[i]) = (5040000,10700)
# (X[i],Y[i]) = (5040000,6600)
# (X[i],Y[i]) = (5033000,4800)
# (X[i],Y[i]) = (5005000,8150)
# (X[i],Y[i]) = (4970000,4410)
# (X[i],Y[i]) = (4970000,7686)
# (X[i],Y[i]) = (4956000,2800)
# (X[i],Y[i]) = (4935000,5948)
# (X[i],Y[i]) = (4907000,4200)
# (X[i],Y[i]) = (4900000,4520)
# (X[i],Y[i]) = (4900000,4095)
# (X[i],Y[i]) = (4900000,4120)
# (X[i],Y[i]) = (4900000,5400)
# (X[i],Y[i]) = (4900000,4770)
# (X[i],Y[i]) = (4900000,6300)
# (X[i],Y[i]) = (4900000,5800)
# (X[i],Y[i]) = (4900000,3000)
# (X[i],Y[i]) = (4900000,2970)
# (X[i],Y[i]) = (4900000,6720)
# (X[i],Y[i]) = (4900000,4646)
# (X[i],Y[i]) = (4900000,12900)
# (X[i],Y[i]) = (4893000,3420)
# (X[i],Y[i]) = (4893000,4995)
# (X[i],Y[i]) = (4865000,4350)
# (X[i],Y[i]) = (4830000,4160)
# (X[i],Y[i]) = (4830000,6040)
# (X[i],Y[i]) = (4830000,6862)
# (X[i],Y[i]) = (4830000,4815)
# (X[i],Y[i]) = (4795000,7000)
# (X[i],Y[i]) = (4795000,8100)
# (X[i],Y[i]) = (4767000,3420)
# (X[i],Y[i]) = (4760000,9166)
# (X[i],Y[i]) = (4760000,6321)
# (X[i],Y[i]) = (4760000,10240)
# (X[i],Y[i]) = (4753000,6440)
# (X[i],Y[i]) = (4690000,5170)
# (X[i],Y[i]) = (4690000,6000)
# (X[i],Y[i]) = (4690000,3630)
# (X[i],Y[i]) = (4690000,9667)
# (X[i],Y[i]) = (4690000,5400)
# (X[i],Y[i]) = (4690000,4320)
# (X[i],Y[i]) = (4655000,3745)
# (X[i],Y[i]) = (4620000,4160)
# (X[i],Y[i]) = (4620000,3880)
# (X[i],Y[i]) = (4620000,5680)
# (X[i],Y[i]) = (4620000,2870)
# (X[i],Y[i]) = (4620000,5010)
# (X[i],Y[i]) = (4613000,4510)
# (X[i],Y[i]) = (4585000,4000)
# (X[i],Y[i]) = (4585000,3840)
# (X[i],Y[i]) = (4550000,3760)
# (X[i],Y[i]) = (4550000,3640)
# (X[i],Y[i]) = (4550000,2550)
# (X[i],Y[i]) = (4550000,5320)
# (X[i],Y[i]) = (4550000,5360)
# (X[i],Y[i]) = (4550000,3520)
# (X[i],Y[i]) = (4550000,8400)
# (X[i],Y[i]) = (4543000,4100)
# (X[i],Y[i]) = (4543000,4990)
# (X[i],Y[i]) = (4515000,3510)
# (X[i],Y[i]) = (4515000,3450)
# (X[i],Y[i]) = (4515000,9860)
# (X[i],Y[i]) = (4515000,3520)
# (X[i],Y[i]) = (4480000,4510)
# (X[i],Y[i]) = (4480000,5885)
# (X[i],Y[i]) = (4480000,4000)
# (X[i],Y[i]) = (4480000,8250)
# (X[i],Y[i]) = (4480000,4040)
# (X[i],Y[i]) = (4473000,6360)
# (X[i],Y[i]) = (4473000,3162)
# (X[i],Y[i]) = (4473000,3510)
# (X[i],Y[i]) = (4445000,3750)
# (X[i],Y[i]) = (4410000,3968)
# (X[i],Y[i]) = (4410000,4900)
# (X[i],Y[i]) = (4403000,2880)
# (X[i],Y[i]) = (4403000,4880)
# (X[i],Y[i]) = (4403000,4920)
# (X[i],Y[i]) = (4382000,4950)
# (X[i],Y[i]) = (4375000,3900)
# (X[i],Y[i]) = (4340000,4500)
# (X[i],Y[i]) = (4340000,1905)
# (X[i],Y[i]) = (4340000,4075)
# (X[i],Y[i]) = (4340000,3500)
# (X[i],Y[i]) = (4340000,6450)
# (X[i],Y[i]) = (4319000,4032)
# (X[i],Y[i]) = (4305000,4400)
# (X[i],Y[i]) = (4305000,10360)
# (X[i],Y[i]) = (4277000,3400)
# (X[i],Y[i]) = (4270000,6360)
# (X[i],Y[i]) = (4270000,6360)
# (X[i],Y[i]) = (4270000,4500)
# (X[i],Y[i]) = (4270000,2175)
# (X[i],Y[i]) = (4270000,4360)
# (X[i],Y[i]) = (4270000,7770)
# (X[i],Y[i]) = (4235000,6650)
# (X[i],Y[i]) = (4235000,2787)
# (X[i],Y[i]) = (4200000,5500)
# (X[i],Y[i]) = (4200000,5040)
# (X[i],Y[i]) = (4200000,5850)
# (X[i],Y[i]) = (4200000,2610)
# (X[i],Y[i]) = (4200000,2953)
# (X[i],Y[i]) = (4200000,2747)
# (X[i],Y[i]) = (4200000,4410)
# (X[i],Y[i]) = (4200000,4000)
# (X[i],Y[i]) = (4200000,2325)
# (X[i],Y[i]) = (4200000,4600)
# (X[i],Y[i]) = (4200000,3640)
# (X[i],Y[i]) = (4200000,5800)
# (X[i],Y[i]) = (4200000,7000)
# (X[i],Y[i]) = (4200000,4079)
# (X[i],Y[i]) = (4200000,3520)
# (X[i],Y[i]) = (4200000,2145)
# (X[i],Y[i]) = (4200000,4500)
# (X[i],Y[i]) = (4193000,8250)
# (X[i],Y[i]) = (4193000,3450)
# (X[i],Y[i]) = (4165000,4840)
# (X[i],Y[i]) = (4165000,4080)
# (X[i],Y[i]) = (4165000,4046)
# (X[i],Y[i]) = (4130000,4632)
# (X[i],Y[i]) = (4130000,5985)
# (X[i],Y[i]) = (4123000,6060)
# (X[i],Y[i]) = (4098500,3600)
# (X[i],Y[i]) = (4095000,3680)
# (X[i],Y[i]) = (4095000,4040)
# (X[i],Y[i]) = (4095000,5600)
# (X[i],Y[i]) = (4060000,5900)
# (X[i],Y[i]) = (4060000,4992)
# (X[i],Y[i]) = (4060000,4340)
# (X[i],Y[i]) = (4060000,3000)
# (X[i],Y[i]) = (4060000,4320)
# (X[i],Y[i]) = (4025000,3630)
# (X[i],Y[i]) = (4025000,3460)
# (X[i],Y[i]) = (4025000,5400)
# (X[i],Y[i]) = (4007500,4500)
# (X[i],Y[i]) = (4007500,3460)
# (X[i],Y[i]) = (3990000,4100)
# (X[i],Y[i]) = (3990000,6480)
# (X[i],Y[i]) = (3990000,4500)
# (X[i],Y[i]) = (3990000,3960)
# (X[i],Y[i]) = (3990000,4050)
# (X[i],Y[i]) = (3920000,7260)
# (X[i],Y[i]) = (3920000,5500)
# (X[i],Y[i]) = (3920000,3000)
# (X[i],Y[i]) = (3920000,3290)
# (X[i],Y[i]) = (3920000,3816)
# (X[i],Y[i]) = (3920000,8080)
# (X[i],Y[i]) = (3920000,2145)
# (X[i],Y[i]) = (3885000,3780)
# (X[i],Y[i]) = (3885000,3180)
# (X[i],Y[i]) = (3850000,5300)
# (X[i],Y[i]) = (3850000,3180)
# (X[i],Y[i]) = (3850000,7152)
# (X[i],Y[i]) = (3850000,4080)
# (X[i],Y[i]) = (3850000,3850)
# (X[i],Y[i]) = (3850000,2015)
# (X[i],Y[i]) = (3850000,2176)
# (X[i],Y[i]) = (3836000,3350)
# (X[i],Y[i]) = (3815000,3150)
# (X[i],Y[i]) = (3780000,4820)
# (X[i],Y[i]) = (3780000,3420)
# (X[i],Y[i]) = (3780000,3600)
# (X[i],Y[i]) = (3780000,5830)
# (X[i],Y[i]) = (3780000,2856)
# (X[i],Y[i]) = (3780000,8400)
# (X[i],Y[i]) = (3773000,8250)
# (X[i],Y[i]) = (3773000,2520)
# (X[i],Y[i]) = (3773000,6930)
# (X[i],Y[i]) = (3745000,3480)
# (X[i],Y[i]) = (3710000,3600)
# (X[i],Y[i]) = (3710000,4040)
# (X[i],Y[i]) = (3710000,6020)
# (X[i],Y[i]) = (3710000,4050)
# (X[i],Y[i]) = (3710000,3584)
# (X[i],Y[i]) = (3703000,3120)
# (X[i],Y[i]) = (3703000,5450)
# (X[i],Y[i]) = (3675000,3630)
# (X[i],Y[i]) = (3675000,3630)
# (X[i],Y[i]) = (3675000,5640)
# (X[i],Y[i]) = (3675000,3600)
# (X[i],Y[i]) = (3640000,4280)
# (X[i],Y[i]) = (3640000,3570)
# (X[i],Y[i]) = (3640000,3180)
# (X[i],Y[i]) = (3640000,3000)
# (X[i],Y[i]) = (3640000,3520)
# (X[i],Y[i]) = (3640000,5960)
# (X[i],Y[i]) = (3640000,4130)
# (X[i],Y[i]) = (3640000,2850)
# (X[i],Y[i]) = (3640000,2275)
# (X[i],Y[i]) = (3633000,3520)
# (X[i],Y[i]) = (3605000,4500)
# (X[i],Y[i]) = (3605000,4000)
# (X[i],Y[i]) = (3570000,3150)
# (X[i],Y[i]) = (3570000,4500)
# (X[i],Y[i]) = (3570000,4500)
# (X[i],Y[i]) = (3570000,3640)
# (X[i],Y[i]) = (3535000,3850)
# (X[i],Y[i]) = (3500000,4240)
# (X[i],Y[i]) = (3500000,3650)
# (X[i],Y[i]) = (3500000,4600)
# (X[i],Y[i]) = (3500000,2135)
# (X[i],Y[i]) = (3500000,3036)
# (X[i],Y[i]) = (3500000,3990)
# (X[i],Y[i]) = (3500000,7424)
# (X[i],Y[i]) = (3500000,3480)
# (X[i],Y[i]) = (3500000,3600)
# (X[i],Y[i]) = (3500000,3640)
# (X[i],Y[i]) = (3500000,5900)
# (X[i],Y[i]) = (3500000,3120)
# (X[i],Y[i]) = (3500000,7350)
# (X[i],Y[i]) = (3500000,3512)
# (X[i],Y[i]) = (3500000,9500)
# (X[i],Y[i]) = (3500000,5880)
# (X[i],Y[i]) = (3500000,12944)
# (X[i],Y[i]) = (3493000,4900)
# (X[i],Y[i]) = (3465000,3060)
# (X[i],Y[i]) = (3465000,5320)
# (X[i],Y[i]) = (3465000,2145)
# (X[i],Y[i]) = (3430000,4000)
# (X[i],Y[i]) = (3430000,3185)
# (X[i],Y[i]) = (3430000,3850)
# (X[i],Y[i]) = (3430000,2145)
# (X[i],Y[i]) = (3430000,2610)
# (X[i],Y[i]) = (3430000,1950)
# (X[i],Y[i]) = (3423000,4040)
# (X[i],Y[i]) = (3395000,4785)
# (X[i],Y[i]) = (3395000,3450)
# (X[i],Y[i]) = (3395000,3640)
# (X[i],Y[i]) = (3360000,3500)
# (X[i],Y[i]) = (3360000,4960)
# (X[i],Y[i]) = (3360000,4120)
# (X[i],Y[i]) = (3360000,4750)
# (X[i],Y[i]) = (3360000,3720)
# (X[i],Y[i]) = (3360000,3750)
# (X[i],Y[i]) = (3360000,3100)
# (X[i],Y[i]) = (3360000,3185)
# (X[i],Y[i]) = (3353000,2700)
# (X[i],Y[i]) = (3332000,2145)
# (X[i],Y[i]) = (3325000,4040)
# (X[i],Y[i]) = (3325000,4775)
# (X[i],Y[i]) = (3290000,2500)
# (X[i],Y[i]) = (3290000,3180)
# (X[i],Y[i]) = (3290000,6060)
# (X[i],Y[i]) = (3290000,3480)
# (X[i],Y[i]) = (3290000,3792)
# (X[i],Y[i]) = (3290000,4040)
# (X[i],Y[i]) = (3290000,2145)
# (X[i],Y[i]) = (3290000,5880)
# (X[i],Y[i]) = (3255000,4500)
# (X[i],Y[i]) = (3255000,3930)
# (X[i],Y[i]) = (3234000,3640)
# (X[i],Y[i]) = (3220000,4370)
# (X[i],Y[i]) = (3220000,2684)
# (X[i],Y[i]) = (3220000,4320)
# (X[i],Y[i]) = (3220000,3120)
# (X[i],Y[i]) = (3150000,3450)
# (X[i],Y[i]) = (3150000,3986)
# (X[i],Y[i]) = (3150000,3500)
# (X[i],Y[i]) = (3150000,4095)
# (X[i],Y[i]) = (3150000,1650)
# (X[i],Y[i]) = (3150000,3450)
# (X[i],Y[i]) = (3150000,6750)
# (X[i],Y[i]) = (3150000,9000)
# (X[i],Y[i]) = (3150000,3069)
# (X[i],Y[i]) = (3143000,4500)
# (X[i],Y[i]) = (3129000,5495)
# (X[i],Y[i]) = (3118850,2398)
# (X[i],Y[i]) = (3115000,3000)
# (X[i],Y[i]) = (3115000,3850)
# (X[i],Y[i]) = (3115000,3500)
# (X[i],Y[i]) = (3087000,8100)
# (X[i],Y[i]) = (3080000,4960)
# (X[i],Y[i]) = (3080000,2160)
# (X[i],Y[i]) = (3080000,3090)
# (X[i],Y[i]) = (3080000,4500)
# (X[i],Y[i]) = (3045000,3800)
# (X[i],Y[i]) = (3010000,3090)
# (X[i],Y[i]) = (3010000,3240)
# (X[i],Y[i]) = (3010000,2835)
# (X[i],Y[i]) = (3010000,4600)
# (X[i],Y[i]) = (3010000,5076)
# (X[i],Y[i]) = (3010000,3750)
# (X[i],Y[i]) = (3010000,3630)
# (X[i],Y[i]) = (3003000,8050)
# (X[i],Y[i]) = (2975000,4352)
# (X[i],Y[i]) = (2961000,3000)
# (X[i],Y[i]) = (2940000,5850)
# (X[i],Y[i]) = (2940000,4960)
# (X[i],Y[i]) = (2940000,3600)
# (X[i],Y[i]) = (2940000,3660)
# (X[i],Y[i]) = (2940000,3480)
# (X[i],Y[i]) = (2940000,2700)
# (X[i],Y[i]) = (2940000,3150)
# (X[i],Y[i]) = (2940000,6615)
# (X[i],Y[i]) = (2870000,3040)
# (X[i],Y[i]) = (2870000,3630)
# (X[i],Y[i]) = (2870000,6000)
# (X[i],Y[i]) = (2870000,5400)
# (X[i],Y[i]) = (2852500,5200)
# (X[i],Y[i]) = (2835000,3300)
# (X[i],Y[i]) = (2835000,4350)
# (X[i],Y[i]) = (2835000,2640)
# (X[i],Y[i]) = (2800000,2650)
# (X[i],Y[i]) = (2800000,3960)
# (X[i],Y[i]) = (2730000,6800)
# (X[i],Y[i]) = (2730000,4000)
# (X[i],Y[i]) = (2695000,4000)
# (X[i],Y[i]) = (2660000,3934)
# (X[i],Y[i]) = (2660000,2000)
# (X[i],Y[i]) = (2660000,3630)
# (X[i],Y[i]) = (2660000,2800)
# (X[i],Y[i]) = (2660000,2430)
# (X[i],Y[i]) = (2660000,3480)
# (X[i],Y[i]) = (2660000,4000)
# (X[i],Y[i]) = (2653000,3185)
# (X[i],Y[i]) = (2653000,4000)
# (X[i],Y[i]) = (2604000,2910)
# (X[i],Y[i]) = (2590000,3600)
# (X[i],Y[i]) = (2590000,4400)
# (X[i],Y[i]) = (2590000,3600)
# (X[i],Y[i]) = (2520000,2880)
# (X[i],Y[i]) = (2520000,3180)
# (X[i],Y[i]) = (2520000,3000)
# (X[i],Y[i]) = (2485000,4400)
# (X[i],Y[i]) = (2485000,3000)
# (X[i],Y[i]) = (2450000,3210)
# (X[i],Y[i]) = (2450000,3240)
# (X[i],Y[i]) = (2450000,3000)
# (X[i],Y[i]) = (2450000,3500)
# (X[i],Y[i]) = (2450000,4840)
# (X[i],Y[i]) = (2450000,7700)
# (X[i],Y[i]) = (2408000,3635)
# (X[i],Y[i]) = (2380000,2475)
# (X[i],Y[i]) = (2380000,2787)
# (X[i],Y[i]) = (2380000,3264)
# (X[i],Y[i]) = (2345000,3640)
# (X[i],Y[i]) = (2310000,3180)
# (X[i],Y[i]) = (2275000,1836)
# (X[i],Y[i]) = (2275000,3970)
# (X[i],Y[i]) = (2275000,3970)
# (X[i],Y[i]) = (2240000,1950)
# (X[i],Y[i]) = (2233000,5300)
# (X[i],Y[i]) = (2135000,3000)
# (X[i],Y[i]) = (2100000,2400)
# (X[i],Y[i]) = (2100000,3000)
# (X[i],Y[i]) = (2100000,3360)
# (X[i],Y[i]) = (1960000,3420)
# (X[i],Y[i]) = (1890000,1700)
# (X[i],Y[i]) = (1890000,3649)
# (X[i],Y[i]) = (1855000,2990)
# (X[i],Y[i]) = (1820000,3000)
# (X[i],Y[i]) = (1767150,2400)
# (X[i],Y[i]) = (1750000,3620)
# (X[i],Y[i]) = (1750000,2910)
# (X[i],Y[i]) = (1750000,3850)

# %%
# Scatter plot 
plt.scatter(X,Y,marker="x", c='r', label = "input")
plt.xlabel("inputs")
plt.ylabel("outputs")
plt.legend()
plt.show()

# %%
#linear regression model y = wx + b
def linear_regression_model(X,w,b):
    f_x = np.zeros(len(X))
    for i in range(len(X)):
        f_x[i] = w * X[i] + b
    return f_x

# initializing the w and b for the regression
w=0.0009
b=1000

# printing the output from the linear regression model
l_r=linear_regression_model(X, w, b)
print(l_r)
# Out:
# [12970.    12025.    12025.    11993.5   11269.    10765.    10135.
#  10135.     9883.     9820.     9820.     9712.9    9379.     9316.
#   9316.     9190.     9190.     9064.     9001.     8969.5    8875.
#   8812.     8780.5    8780.5    8717.5    8686.     8616.7    8560.
#   8560.     8560.     8560.     8560.     8465.5    8371.     8308.
#   8272.846  8238.7    8182.     8166.25   8119.     8087.5    8056.
#   7930.     7930.     7804.     7804.     7772.5    7741.     7709.5
#   7678.     7678.     7678.     7615.     7615.     7615.     7615.
#   7608.7    7520.5    7489.     7489.     7426.     7363.     7363.
#   7331.5    7300.     7237.     7237.     7205.5    7174.     7111.
#   7111.     7079.5    7048.     7016.5    6985.     6985.     6985.
#   6985.     6985.     6985.     6966.1    6953.5    6953.5    6922.
#   6859.     6859.     6859.     6827.5    6827.5    6796.     6796.
#   6777.1    6764.5    6670.     6670.     6670.     6670.     6670.
#   6663.7    6638.5    6607.     6607.     6575.5    6575.5    6575.5
#   6544.     6544.     6512.5    6496.75   6481.     6481.     6481.
#   6474.7    6474.7    6418.     6418.     6418.     6355.     6355.
#   6355.     6355.     6355.     6355.     6355.     6355.     6348.7
#   6292.     6292.     6285.7    6285.7    6279.4    6229.     6229.
#   6229.     6222.7    6197.5    6166.     6166.     6166.     6166.
#   6166.     6087.25   6040.     6040.     6040.     6040.     6040.
#   6040.     6040.     6040.     6040.     6008.5    6008.5    5977.
#   5977.     5977.     5970.7    5945.5    5945.5    5914.     5914.
#   5914.     5914.     5882.5    5851.     5844.7    5788.     5756.5
#   5725.     5725.     5725.     5725.     5725.     5725.     5725.
#   5725.     5725.     5718.7    5706.1    5693.5    5693.5    5693.5
#   5630.5    5630.5    5599.     5599.     5599.     5599.     5567.5
#   5536.     5536.     5536.     5536.     5529.7    5504.5    5473.
#   5473.     5460.4    5441.5    5416.3    5410.     5410.     5410.
#   5410.     5410.     5410.     5410.     5410.     5410.     5410.
#   5410.     5410.     5403.7    5403.7    5378.5    5347.     5347.
#   5347.     5347.     5315.5    5315.5    5290.3    5284.     5284.
#   5284.     5277.7    5221.     5221.     5221.     5221.     5221.
#   5221.     5189.5    5158.     5158.     5158.     5158.     5158.
#   5151.7    5126.5    5126.5    5095.     5095.     5095.     5095.
#   5095.     5095.     5095.     5088.7    5088.7    5063.5    5063.5
#   5063.5    5063.5    5032.     5032.     5032.     5032.     5032.
#   5025.7    5025.7    5025.7    5000.5    4969.     4969.     4962.7
#   4962.7    4962.7    4943.8    4937.5    4906.     4906.     4906.
#   4906.     4906.     4887.1    4874.5    4874.5    4849.3    4843.
#   4843.     4843.     4843.     4843.     4843.     4811.5    4811.5
#   4780.     4780.     4780.     4780.     4780.     4780.     4780.
#   4780.     4780.     4780.     4780.     4780.     4780.     4780.
#   4780.     4780.     4780.     4773.7    4773.7    4748.5    4748.5
#   4748.5    4717.     4717.     4710.7    4688.65   4685.5    4685.5
#   4685.5    4654.     4654.     4654.     4654.     4654.     4622.5
#   4622.5    4622.5    4606.75   4606.75   4591.     4591.     4591.
#   4591.     4591.     4528.     4528.     4528.     4528.     4528.
#   4528.     4528.     4496.5    4496.5    4465.     4465.     4465.
#   4465.     4465.     4465.     4465.     4452.4    4433.5    4402.
#   4402.     4402.     4402.     4402.     4402.     4395.7    4395.7
#   4395.7    4370.5    4339.     4339.     4339.     4339.     4339.
#   4332.7    4332.7    4307.5    4307.5    4307.5    4307.5    4276.
#   4276.     4276.     4276.     4276.     4276.     4276.     4276.
#   4276.     4269.7    4244.5    4244.5    4213.     4213.     4213.
#   4213.     4181.5    4150.     4150.     4150.     4150.     4150.
#   4150.     4150.     4150.     4150.     4150.     4150.     4150.
#   4150.     4150.     4150.     4150.     4150.     4143.7    4118.5
#   4118.5    4118.5    4087.     4087.     4087.     4087.     4087.
#   4087.     4080.7    4055.5    4055.5    4055.5    4024.     4024.
#   4024.     4024.     4024.     4024.     4024.     4024.     4017.7
#   3998.8    3992.5    3992.5    3961.     3961.     3961.     3961.
#   3961.     3961.     3961.     3961.     3929.5    3929.5    3910.6
#   3898.     3898.     3898.     3898.     3835.     3835.     3835.
#   3835.     3835.     3835.     3835.     3835.     3835.     3828.7
#   3816.1    3806.965  3803.5    3803.5    3803.5    3778.3    3772.
#   3772.     3772.     3772.     3740.5    3709.     3709.     3709.
#   3709.     3709.     3709.     3709.     3702.7    3677.5    3664.9
#   3646.     3646.     3646.     3646.     3646.     3646.     3646.
#   3646.     3583.     3583.     3583.     3583.     3567.25   3551.5
#   3551.5    3551.5    3520.     3520.     3457.     3457.     3425.5
#   3394.     3394.     3394.     3394.     3394.     3394.     3394.
#   3387.7    3387.7    3343.6    3331.     3331.     3331.     3268.
#   3268.     3268.     3236.5    3236.5    3205.     3205.     3205.
#   3205.     3205.     3205.     3167.2    3142.     3142.     3142.
#   3110.5    3079.     3047.5    3047.5    3047.5    3016.     3009.7
#   2921.5    2890.     2890.     2890.     2764.     2701.     2701.
#   2669.5    2638.     2590.435  2575.     2575.     2575.   ]

# %%
#plot linear regression model
plt.plot(X,l_r, color = "skyblue")
plt.scatter(X,Y,marker="x", c='r', label = "input")
plt.xlabel("inputs")
plt.ylabel("outputs")
plt.legend()
plt.show()

# %% [markdown]
# ## ***COST FUNCTION***

# %%
def cost_function_linear_regression(pred_y,Y,m):
    sum_cost=0
    
    for i in range(m):
        #pred_y=w*X[i]+b
        sum_cost=sum_cost+(pred_y[i]-Y[i])**2
    cost_total=(1/2*m)*sum_cost
    return cost_total

# %%
pred_y=linear_regression_model(X,w,b)
m=len(X)
print(cost_function_linear_regression(pred_y,Y,m))
# Out:
# 540574327559.3141

# %% [markdown]
# ## ***Gradient descents***

# %%
#Gradient descent
def gradient_descent_cost_function(X,Y,w,b):
    j_dw = 0 
    j_db = 0
    for i in range(m):
        f_x = w * X[i] + b
        j_dw = j_dw + (f_x - Y[i]) * X[i]
        j_db = j_db + (f_x - Y[i])

    j_dw = j_dw / m
    j_db = j_db / m
    return j_dw,j_db

# %%
j_dw,j_db = gradient_descent_cost_function(X,Y,w,b)
print(f"j_dw = {j_dw} and j_db = {j_db}")
# Out:
# j_dw = 1636258654.0013578 and j_db = 139.5150385321099

# %%
#Gradient descent algorithm
def gradient_descent_algorithm(X,Y,w,b,learning_rate,gradient_descent_cost_function,iteration):
    w = w
    b = b
    for i in range(iteration):
        j_dw,j_db = gradient_descent_cost_function(X,Y,w,b)
        w = w - learning_rate * j_dw
        b = b - learning_rate * j_db
    return w,b

# %%
w = 0
b = 0
learning_rate = 0.0001 # Best range for the learning rate is 0.001 to 0.0001, where 0.1 to 0.00001 is the actual rate range
iteration = 23
w,b = gradient_descent_algorithm(X,Y,w,b,learning_rate,gradient_descent_cost_function,iteration)

# %%
print(f"w = {w} and b = {b}")
l_r=linear_regression_model(X, w, b)
# Out:
# w = 4.310775774645507e+213 and b = 7.83872437788356e+206

# %%
#plot linear regression model
plt.plot(X,l_r, color = "skyblue")
plt.scatter(X,Y,marker="x", c='r', label = "input")
plt.xlabel("inputs")
plt.ylabel("outputs")
plt.legend()
plt.show()

# %% [markdown]
# ## ***Lo*** ##

# %%
def panelty(w):
    sum = 0
    for i in range(m):
        sum += w**2
    return sum
