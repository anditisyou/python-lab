# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv("labeled_data.csv")
X = df['tweet']
y = df['class'].value_counts()
plt.bar(y.index, y.values,width=0.25,color = "red")
plt.show()

# %%
df['hate_speech/offensive_language']=[
